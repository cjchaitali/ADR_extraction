# %%
import numpy as np

import pandas as pd

from keras.models import Sequential

from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D

from sklearn.model_selection import train_test_split

from sklearn.feature_extraction.text import CountVectorizer

from keras.preprocessing.text import Tokenizer

from keras.preprocessing.sequence import pad_sequences

from keras.utils.np_utils import to_categorical

import re

# %%
df = pd.read_csv("Mirena_TCS.csv", encoding='cp1252', error_bad_lines=False)
df.head()
# Out:
#    Sr No.                                     Reported_Event  \
# 0       1  1) IUD migrated to lower uterine segment/ IUS ...
# 1       2             1) Patient removed the IUD by herself;
# 2       3  1) Patient was perforated during insertion pro...
# 3       4  1) one to the arms of the T body was embeded i...
# 4       5                  1) Mirena was partially expelled;
#
#           EVENT Preferred Term (Seriousness) (Event)  \
# 0  1) Device dislocation (s); \n2) Genital haemor...
# 1  1) Intentional medical device removal by patie...
# 2  1) Uterine perforation (s); \n2) Complication ...
# 3   1) Embedded device (s); \n2) Abdominal pain (n);
# 4                           1) Device expulsion (n);
#
#                  EVENT_Lower_Level_Term(Seriousness)  \
# 0  1) IUD migration (s); \n2) Genital bleeding (s...
# 1  1) Intentional medical device removal by patie...
# 2  1) Uterine perforation post procedural (s); \n...
# 3      1) IUD embedded (s); \n2) Abdominal pain (n);
# 4                   1) Partial expulsion of IUD (n);
#
#                             EVENT Onset Date (Event)  \
# 0  1) Device dislocation : 2016; \n2) Genital hae...
# 1  1) Intentional medical device removal by patie...
# 2  1) Uterine perforation : --; \n2) Complication...
# 3  1) Embedded device : 2016; \n2) Abdominal pain...
# 4                          1) Device expulsion : --;
#
#                   EVENT Seriousness Criteria (Event)  \
# 0   1) Device dislocation :  Medically Significan...
# 1                                                NaN
# 2   1) Uterine perforation :  Medically Significa...
# 3      1) Embedded device :  Medically Significant /
# 4                                                NaN
#
#           EVENT Company Causality (Event Assessment)  \
# 0  1) SAG0224B.282 - 1) Device dislocation : rela...
# 1  1) Study Drug - 1) Intentional medical device ...
# 2  1) SAG0224B.282 - 1) Uterine perforation : rel...
# 3     1) SAG0224B.282 - 1) Embedded device : related
# 4      1) Study Drug - 1) Device expulsion : related
#
#          EVENT Reporter Causality (Event Assessment)  \
# 0  1) SAG0224B.282 - 1) Device dislocation : not ...
# 1  1) Study Drug - 1) Intentional medical device ...
# 2  1) SAG0224B.282 - 1) Uterine perforation : not...
# 3  1) SAG0224B.282 - 1) Embedded device : not rep...
# 4  1) Study Drug - 1) Device expulsion : not repo...
#
#   SUSPECT PRODUCT Product (as reported) SUSPECT PRODUCT Product Name (Suspect)
# 0                                 1) --                              1) Mirena
# 1                             1) Mirena                              1) Mirena
# 2                                 1) --                              1) Mirena
# 3                                 1) --                              1) Mirena
# 4                             1) Mirena                              1) Mirena

# %%
df.columns
# Out:
# Index(['Sr No.', 'Reported_Event',
#        'EVENT Preferred Term (Seriousness) (Event)',
#        'EVENT_Lower_Level_Term(Seriousness)', 'EVENT Onset Date (Event)',
#        'EVENT Seriousness Criteria (Event)',
#        'EVENT Company Causality (Event Assessment)',
#        'EVENT Reporter Causality (Event Assessment)',
#        'SUSPECT PRODUCT Product (as reported)',
#        'SUSPECT PRODUCT Product Name (Suspect)'],
#       dtype='object')

# %% [markdown]
# ## drop unwanted columns

# %%
df.drop(columns = ['Sr No.','EVENT Preferred Term (Seriousness) (Event)', 
                   'EVENT Onset Date (Event)',
                   'EVENT Seriousness Criteria (Event)',
                   'EVENT Company Causality (Event Assessment)',
                   'EVENT Reporter Causality (Event Assessment)',
                   'SUSPECT PRODUCT Product (as reported)',
                   'SUSPECT PRODUCT Product Name (Suspect)'],inplace = True)
df.head()
# Out:
#                                       Reported_Event  \
# 0  1) IUD migrated to lower uterine segment/ IUS ...
# 1             1) Patient removed the IUD by herself;
# 2  1) Patient was perforated during insertion pro...
# 3  1) one to the arms of the T body was embeded i...
# 4                  1) Mirena was partially expelled;
#
#                  EVENT_Lower_Level_Term(Seriousness)
# 0  1) IUD migration (s); \n2) Genital bleeding (s...
# 1  1) Intentional medical device removal by patie...
# 2  1) Uterine perforation post procedural (s); \n...
# 3      1) IUD embedded (s); \n2) Abdominal pain (n);
# 4                   1) Partial expulsion of IUD (n);

# %% [markdown]
# ## convert to lower case

# %%
df["Reported_Event"]=df["Reported_Event"].str.lower()
df["EVENT_Lower_Level_Term(Seriousness)"]=df["EVENT_Lower_Level_Term(Seriousness)"].str.lower()
df.head()
# Out:
#                                       Reported_Event  \
# 0  1) iud migrated to lower uterine segment/ ius ...
# 1             1) patient removed the iud by herself;
# 2  1) patient was perforated during insertion pro...
# 3  1) one to the arms of the t body was embeded i...
# 4                  1) mirena was partially expelled;
#
#                  EVENT_Lower_Level_Term(Seriousness)
# 0  1) iud migration (s); \n2) genital bleeding (s...
# 1  1) intentional medical device removal by patie...
# 2  1) uterine perforation post procedural (s); \n...
# 3      1) iud embedded (s); \n2) abdominal pain (n);
# 4                   1) partial expulsion of iud (n);

# %% [markdown]
# ## removal of digits & words containing digits

# %%
df['Reported_Event']=df['Reported_Event'].apply(lambda x: re.sub('\w*\d\w*','', x))
df['EVENT_Lower_Level_Term(Seriousness)']=df['EVENT_Lower_Level_Term(Seriousness)'].apply(lambda x: re.sub('\w*\d\w*','', x))
df.head()
# Out:
#                                       Reported_Event  \
# 0  ) iud migrated to lower uterine segment/ ius n...
# 1              ) patient removed the iud by herself;
# 2  ) patient was perforated during insertion proc...
# 3  ) one to the arms of the t body was embeded in...
# 4                   ) mirena was partially expelled;
#
#                  EVENT_Lower_Level_Term(Seriousness)
# 0  ) iud migration (s); \n) genital bleeding (s);...
# 1  ) intentional medical device removal by patien...
# 2  ) uterine perforation post procedural (s); \n)...
# 3        ) iud embedded (s); \n) abdominal pain (n);
# 4                    ) partial expulsion of iud (n);

# %%
#the string.punctuation in python contains the following punctuation symbols
#     !"#$%&\'()*+,-./:;<=>?@[\\]^_{|}~`


#import spacy
import string
df["Reported_Event"] = df["Reported_Event"].astype(str)
df["EVENT_Lower_Level_Term(Seriousness)"] = df["EVENT_Lower_Level_Term(Seriousness)"].astype(str)
PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(Event):
    return Event.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

df["Reported_Event"]= df["Reported_Event"].apply(lambda Event: remove_punctuation(Event))
df["EVENT_Lower_Level_Term(Seriousness)"]= df["EVENT_Lower_Level_Term(Seriousness)"].apply(lambda Event: remove_punctuation(Event))
df.head()
# Out:
#                                       Reported_Event  \
# 0   iud migrated to lower uterine segment ius not...
# 1                 patient removed the iud by herself
# 2   patient was perforated during insertion proce...
# 3   one to the arms of the t body was embeded in ...
# 4                      mirena was partially expelled
#
#                  EVENT_Lower_Level_Term(Seriousness)
# 0   iud migration s \n genital bleeding s \n post...
# 1    intentional medical device removal by patient n
# 2   uterine perforation post procedural s \n devi...
# 3                 iud embedded s \n abdominal pain n
# 4                         partial expulsion of iud n

# %%
# Remove Emails
df["Reported_Event"] = [re.sub('\S*@\S*\s?', '', sent) for sent in df["Reported_Event"]]
df["EVENT_Lower_Level_Term(Seriousness)"] = [re.sub('\S*@\S*\s?', '', sent) for sent in df["EVENT_Lower_Level_Term(Seriousness)"]]

df.head()
# Out:
#                                       Reported_Event  \
# 0   iud migrated to lower uterine segment ius not...
# 1                 patient removed the iud by herself
# 2   patient was perforated during insertion proce...
# 3   one to the arms of the t body was embeded in ...
# 4                      mirena was partially expelled
#
#                  EVENT_Lower_Level_Term(Seriousness)
# 0   iud migration s \n genital bleeding s \n post...
# 1    intentional medical device removal by patient n
# 2   uterine perforation post procedural s \n devi...
# 3                 iud embedded s \n abdominal pain n
# 4                         partial expulsion of iud n

# %%
# Remove new line characters
df["Reported_Event"] = [re.sub('\s+', ' ', sent) for sent in df["Reported_Event"]]
df["EVENT_Lower_Level_Term(Seriousness)"] = [re.sub('\s+', ' ', sent) for sent in df["EVENT_Lower_Level_Term(Seriousness)"]]
df.head(20)
# Out:
#                                        Reported_Event  \
# 0    iud migrated to lower uterine segment ius not...
# 1                  patient removed the iud by herself
# 2    patient was perforated during insertion proce...
# 3    one to the arms of the t body was embeded in ...
# 4                       mirena was partially expelled
# 5                         mirena expelled with tampon
# 6    embedmentinto uterine myometruim not throughp...
# 7    pregnant weeks and days pregnant tried to loc...
# 8                                 device was expelled
# 9    coming out “on a friday” when she was at home...
# 10                                           fell out
# 11   a new york federal judge has ruled in favor o...
# 12                                  spotting with iud
# 13                      uncontrolled vaginal bleeding
# 14   the device was discovered to be partially sti...
# 15                              she has gained pounds
# 16                                     heavy bleeding
# 17   stenotic cervical os too painful unable to pa...
# 18   changes in my biology changes in my personali...
# 19
#
#                   EVENT_Lower_Level_Term(Seriousness)
# 0    iud migration s genital bleeding s post coita...
# 1     intentional medical device removal by patient n
# 2    uterine perforation post procedural s device ...
# 3                     iud embedded s abdominal pain n
# 4                          partial expulsion of iud n
# 5                                      iud expelled n
# 6    iud embedded s device insertion failed n devi...
# 7    pregnancy with iud s iud dislocation s vomiti...
# 8                                      iud expelled n
# 9                                      iud expelled n
# 10                                     iud expelled n
# 11                              internal injury nos n
# 12                                 spotting vaginal n
# 13                                 vaginal bleeding n
# 14                         partial expulsion of iud n
# 15                                      weight gain n
# 16                                 bleeding genital s
# 17   uterine cervix stenosis n procedural pain n d...
# 18   adverse drug reaction nos n personality chang...
# 19            cervical intraepithelial neoplasia ii s

# %% [raw]
# # Remove quotes
# df["Reported_Event"] = [re.sub("\'"," ", sent) for sent in df["Reported_Event"]]
# df["EVENT_Lower_Level_Term(Seriousness)"] = [re.sub("\'"," ", sent) for sent in df["EVENT_Lower_Level_Term(Seriousness)"]]
# df.head(20)

# %% [markdown]
# ## Stop word removal

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['n','s'])
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'n', 's']

# %%
#STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in stop_words])

# %%
df["Reported_Event"] = df["Reported_Event"].apply(lambda text: remove_stopwords(text))
df["EVENT_Lower_Level_Term(Seriousness)"] = df["EVENT_Lower_Level_Term(Seriousness)"].apply(lambda text: remove_stopwords(text))

df.head()
# Out:
#                                       Reported_Event  \
# 0  iud migrated lower uterine segment ius fundal ...
# 1                                patient removed iud
# 2  patient perforated insertion process attending...
# 3  one arms body embeded patient myometriumone ar...
# 4                          mirena partially expelled
#
#                  EVENT_Lower_Level_Term(Seriousness)
# 0  iud migration genital bleeding post coital ble...
# 1         intentional medical device removal patient
# 2  uterine perforation post procedural device ins...
# 3                        iud embedded abdominal pain
# 4                              partial expulsion iud

# %%
import torch
from transformers import BertTokenizer, BertModel
import argparse
import logging
import torch
from transformers import BertConfig, BertForPreTraining, load_tf_weights_in_bert
logging.basicConfig(level=logging.INFO)

# %%
pip install spark-nlp==3.0.1
# Out:
# Collecting spark-nlp==3.0.1
#   Downloading spark_nlp-3.0.1-py2.py3-none-any.whl (146 kB)
# Installing collected packages: spark-nlp
# Successfully installed spark-nlp-3.0.1
# Note: you may need to restart the kernel to use updated packages.
