# %% [markdown]
# <a href="https://colab.research.google.com/github/cjchaitali/ADR_extraction/blob/main/NER_BIO_tag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.feature_extraction.text import CountVectorizer

import re

import torch

# %%
df = pd.read_csv("Mirena_TCS1.csv", encoding='cp1252', error_bad_lines=False)
df.head()
# Out:
#    Sr No.  ... SUSPECT PRODUCT Product Name (Suspect)
# 0       1  ...                              1) Mirena
# 1       2  ...                              1) Mirena
# 2       3  ...                              1) Mirena
# 3       4  ...                              1) Mirena
# 4       5  ...                              1) Mirena
#
# [5 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['Sr No.', 'Reported_Event',
#        'EVENT Preferred Term (Seriousness) (Event)', 'EVENT_Lower_Level_Term',
#        'EVENT Onset Date (Event)', 'EVENT Seriousness Criteria (Event)',
#        'EVENT Company Causality (Event Assessment)',
#        'EVENT Reporter Causality (Event Assessment)',
#        'SUSPECT PRODUCT Product (as reported)',
#        'SUSPECT PRODUCT Product Name (Suspect)'],
#       dtype='object')

# %%
df.drop(columns = ['Sr No.','EVENT Preferred Term (Seriousness) (Event)', 
                   'EVENT_Lower_Level_Term',
                   'EVENT Onset Date (Event)',
                   'EVENT Seriousness Criteria (Event)',
                   'EVENT Company Causality (Event Assessment)',
                   'EVENT Reporter Causality (Event Assessment)',
                   'SUSPECT PRODUCT Product (as reported)',
                   'SUSPECT PRODUCT Product Name (Suspect)'],inplace = True)
df.head()
# Out:
#                                       Reported_Event
# 0  1) IUD migrated to lower uterine segment/ IUS ...
# 1             1) Patient removed the IUD by herself;
# 2  1) Patient was perforated during insertion pro...
# 3  1) one to the arms of the T body was embeded i...
# 4                  1) Mirena was partially expelled;

# %%
df['Reported_Event']=df['Reported_Event'].apply(lambda x: re.sub('\w*\d\w*','', x))
df.head()
# Out:
#                                       Reported_Event
# 0  ) IUD migrated to lower uterine segment/ IUS n...
# 1              ) Patient removed the IUD by herself;
# 2  ) Patient was perforated during insertion proc...
# 3  ) one to the arms of the T body was embeded in...
# 4                   ) Mirena was partially expelled;

# %%
import string
df["Reported_Event"] = df["Reported_Event"].astype(str)
PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(Event):
    return Event.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

df["Reported_Event"]= df["Reported_Event"].apply(lambda Event: remove_punctuation(Event))

# %%
df.head()
df.to_csv('Events.csv')

# %%
# !pip install simpletransformers
# Out:
# ...
#      |████████████████████████████████| 215kB 7.8MB/s
# ...
#      |████████████████████████████████| 3.3MB 11.4MB/s
# ...
#      |████████████████████████████████| 81kB 11.0MB/s
# ...
#      |████████████████████████████████| 1.2MB 43.2MB/s
# ...
#      |████████████████████████████████| 51kB 7.7MB/s
# ...
#      |████████████████████████████████| 122kB 42.6MB/s
# ...
#      |████████████████████████████████| 225kB 51.1MB/s
# ...
#      |████████████████████████████████| 2.1MB 49.2MB/s
# ...
#      |████████████████████████████████| 8.2MB 22.9MB/s
# ...
#      |████████████████████████████████| 2.1MB 52.9MB/s
# ...
#      |████████████████████████████████| 112kB 55.5MB/s
# ...
#      |████████████████████████████████| 245kB 51.4MB/s
# ...
#      |████████████████████████████████| 102kB 12.3MB/s
# ...
#      |████████████████████████████████| 163kB 54.8MB/s
# ...
#      |████████████████████████████████| 133kB 63.7MB/s
# ...
#      |████████████████████████████████| 81kB 12.1MB/s
# ...
#      |████████████████████████████████| 4.2MB 64.2MB/s
# ...

# %%
import pandas as pd
data = pd.read_csv("Mirena_NER_data.csv",encoding="latin1" )

# %%
data.head(20)
# Out:
#      Sentence #       Word Tag
# 0   Sentence: 1        IUD   O
# 1           NaN   migrated   B
# 2           NaN         to   O
# 3           NaN      lower   I
# 4           NaN    uterine   I
# 5           NaN    segment   I
# 6           NaN        IUS   O
# 7           NaN        not   O
# 8           NaN         in   O
# 9           NaN     fundal   O
# 10          NaN   position   O
# 11  Sentence: 2    Patient   O
# 12          NaN    removed   B
# 13          NaN        the   I
# 14          NaN        IUD   I
# 15          NaN         by   O
# 16          NaN    herself   O
# 17  Sentence: 3     Mirena   B
# 18          NaN        was   O
# 19          NaN  partially   I

# %%
data =data.fillna(method ="ffill")
data.head(20)
# Out:
#      Sentence #       Word Tag
# 0   Sentence: 1        IUD   O
# 1   Sentence: 1   migrated   B
# 2   Sentence: 1         to   O
# 3   Sentence: 1      lower   I
# 4   Sentence: 1    uterine   I
# 5   Sentence: 1    segment   I
# 6   Sentence: 1        IUS   O
# 7   Sentence: 1        not   O
# 8   Sentence: 1         in   O
# 9   Sentence: 1     fundal   O
# 10  Sentence: 1   position   O
# 11  Sentence: 2    Patient   O
# 12  Sentence: 2    removed   B
# 13  Sentence: 2        the   I
# 14  Sentence: 2        IUD   I
# 15  Sentence: 2         by   O
# 16  Sentence: 2    herself   O
# 17  Sentence: 3     Mirena   B
# 18  Sentence: 3        was   O
# 19  Sentence: 3  partially   I

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

data["Sentence #"] = LabelEncoder().fit_transform(data["Sentence #"] )
data.head(20)
# Out:
#     Sentence #       Word Tag
# 0            0        IUD   O
# 1            0   migrated   B
# 2            0         to   O
# 3            0      lower   I
# 4            0    uterine   I
# 5            0    segment   I
# 6            0        IUS   O
# 7            0        not   O
# 8            0         in   O
# 9            0     fundal   O
# 10           0   position   O
# 11           6    Patient   O
# 12           6    removed   B
# 13           6        the   I
# 14           6        IUD   I
# 15           6         by   O
# 16           6    herself   O
# 17           7     Mirena   B
# 18           7        was   O
# 19           7  partially   I

# %%
data.rename(columns={"Sentence #":"sentence_id","Word":"words","Tag":"labels"}, inplace =True)
data["labels"] = data["labels"].str.upper()

# %%
X= data[["sentence_id","words"]]
Y =data["labels"]

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size =0.2)

# %%
train_data = pd.DataFrame({"sentence_id":x_train["sentence_id"],"words":x_train["words"],"labels":y_train})
test_data = pd.DataFrame({"sentence_id":x_test["sentence_id"],"words":x_test["words"],"labels":y_test})

# %%
train_data
# Out:
#     sentence_id    words labels
# 3             0    lower      I
# 11            6  Patient      O
# 4             0  uterine      I
# 49           10   pounds      I
# 58           13    brain      B
# ..          ...      ...    ...
# 28            8   locate      O
# 78            4        a      O
# 82            5  allergy      I
# 15            6       by      O
# 0             0      IUD      O
#
# [66 rows x 3 columns]

# %%
from simpletransformers.ner import NERModel,NERArgs

# %%
label = data["labels"].unique().tolist()
label
# Out:
# ['O', 'B', 'I']

# %%
args = NERArgs()
args.num_train_epochs = 2
args.learning_rate = 1e-4
args.overwrite_output_dir =True
args.train_batch_size = 32
args.eval_batch_size = 32

# %%
model = NERModel('bert', 'bert-base-cased',labels=label,args =args, use_cuda= False)
# Out:
# ...
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForTokenClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model.train_model(train_data,eval_data = test_data,acc=accuracy_score)
# Out:
# ...
# (2, 1.0975452661514282)

# %%
result, model_outputs, preds_list = model.eval_model(test_data)
# Out:
# ...
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
result
# Out:
# {'eval_loss': 0.8826653361320496,
#  'f1_score': 0.0,
#  'precision': 0.0,
#  'recall': 0.0}

# %%
prediction, model_output = model.predict([" IUD perforated through her uterus and it is in her abdomen. anxiety attack panic anxiety syndrome. increased heart rate"])

# %%
prediction
# Out:
# [[{'IUD': 'O'},
#   {'perforated': 'I'},
#   {'through': 'O'},
#   {'her': 'O'},
#   {'uterus': 'I'},
#   {'and': 'O'},
#   {'it': 'O'},
#   {'is': 'O'},
#   {'in': 'O'},
#   {'her': 'O'},
#   {'abdomen.': 'O'},
#   {'anxiety': 'O'},
#   {'attack': 'O'},
#   {'panic': 'O'},
#   {'anxiety': 'O'},
#   {'syndrome.': 'O'},
#   {'increased': 'O'},
#   {'heart': 'O'},
#   {'rate': 'O'}]]
